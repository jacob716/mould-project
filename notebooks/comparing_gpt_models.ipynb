# %%
import pandas as pd
import numpy as np

# %%
o4mini_csv = pd.read_csv("../extracted_reports_mini.csv")
o4_csv = pd.read_csv("../extracted_reports.csv")

# %%
o4mini_csv
# Out:
#                                      property_type  \
# 0  semi-detached 2 bedroom ground floor maisonette
# 1             three-bedroom semi-detached dwelling
# 2                    ground floor one-bedroom flat
# 3           semi-detached three-bedroomed dwelling
# 4                    two-bedroom ground floor flat
# 5       ground floor flat in a purpose-built block
# 6             three-bedroom semi-detached bungalow
# 7          top floor flat in a purpose-built block
# 8                     two bedroom first floor flat
#
#                                            wall_type            age  \
# 0                                        cavity wall  not mentioned
# 1                                        cavity wall  not mentioned
# 2                                        cavity wall  not mentioned
# 3                                        cavity wall           2023
# 4                                        cavity wall      2020/2021
# ...

# %%
o4_csv
# Out:
#                                      property_type  \
# 0  semi-detached 2 bedroom ground floor maisonette
# 1             semi-detached three-bedroom dwelling
# 2                    ground floor one-bedroom flat
# 3           semi-detached three-bedroomed dwelling
# 4                    two-bedroom ground floor flat
# 5                                ground floor flat
# 6                 semi-detached 3-bedroom bungalow
# 7                                   top floor flat
# 8                     two bedroom first floor flat
#
#                                            wall_type            age  \
# 0                                        cavity wall  not mentioned
# 1                                        cavity wall  not mentioned
# 2                                        cavity wall  not mentioned
# 3                                        cavity wall     circa 2023
# 4                                        cavity wall      2020/2021
# ...

# %%
o4mini_full = pd.read_csv('../extracted_reports.csv')

# %%
o4mini_full
# Out:
#                                                       property_type  \
# 0                               two-bedroom end of terrace dwelling
# 1                                                     semi-detached
# 2   end of terrace dwelling converted into separate living quarters
# 3                        ground floor flat in a purpose-built block
# 4                                       modern mid-terrace dwelling
# ..                                                              ...
# 91                       ground floor flat in a purpose-built block
# 92         top floor 4 bedroom dwelling converted from office space
# 93                                           semi-detached dwelling
# 94                                                         bungalow
# 95                               two-bedroom semi-detached dwelling
#
#                                               wall_type             age  \
# 0                          solid brick and cavity brick            1965
# ...

# %%
o4mini_full['window_type'].unique()
# Out:
# array(['UPVC', 'not mentioned', 'uPVC', 'trickle vents',
#        'timber frame casement', 'uPVC and timber sash',
#        'timber box sash windows', 'timber and uPVC',
#        'uPVC with sash windows', 'uPVC with trickle vents'], dtype=object)

# %%
print(o4mini_full.iloc[2])
# Out:
# property_type          end of terrace dwelling converted into separate living quarters
# wall_type                          solid internal walls over timber suspended flooring
# age                                                                      not mentioned
# issue_type                                                                        damp
# orientation                                                              not mentioned
# ventilation                    single extraction unit in kitchen, trickle vents closed
# window_type                                                                       uPVC
# occupancy                                                                     3 people
# drying_clothes                                                                     yes
# where_else_is_mould                                        lounge, bedroom 2, bathroom
# filename                                                         David_Bly_LU1 (2).pdf
# ...

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)  # No limit on string length
pd.set_option("display.max_columns", None)   # Show all columns if needed
