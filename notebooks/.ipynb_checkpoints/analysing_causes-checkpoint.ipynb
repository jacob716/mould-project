# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../csv_files/merged_reports_categorised.csv")

# %%
non_ventilation = df[
    (df["cause_primary_categorised"] != "poor ventilation") &
    (df["cause_secondary_categorised"] != "poor ventilation")
]

# %%
non_ventilation
# Out:
#                                       property_type      wall_type  \
# 6                     one-bedroom ground floor flat         cavity
# 8                                 ground floor flat         cavity
# 9                   two bedroomed ground floor flat         cavity
# 12                           semi-detached dwelling         cavity
# 18            three-bedroom end of terrace dwelling         cavity
# 25                    two-bedroom ground floor flat         cavity
# 26         modernised detached 3 bedroomed dwelling  not mentioned
# 34                          end of terrace dwelling          solid
# 37                    ground floor one-bedroom flat         cavity
# 38                              semi-detached house         cavity
# 49                 1-bedroom semi-detached bungalow         cavity
# 54                    two-bedroom ground floor flat          solid
# 61                    two-bedroom ground floor flat         cavity
# ...
