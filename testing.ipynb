# %%
import pdfplumber
from src.extract import extract_raw_text, clean_raw_text, extract_atmospheric_conditions, extract_atmospheric_table
from src.classify import identify_features
import os

# %%
raw_text = extract_raw_text("reports/David_Bly_BN17.pdf")

# %%
print(raw_text)
# Out:
# Cornerstone Technical Report
# Our ref: Author: S3
# Name Client
# Address BN17 Contact
# Date of visit 15th July 2025
# Time of visit 09:30 Hrs
# Scope
# Following instruction from ……………………., attend the above property to undertake a damp related survey
# to aid reported ongoing issues.
# Report
# 1.0 Property:
# The property is a ground floor one-bedroom flat of cavity
# wall construction and a solid floor.
# 2.0 Incident:
# A damp related survey is requested following previous
# issues raised aligned to the health of the dwelling.
# 3.0 Conclusion:
# On arrival, the author was advised by a relative of the
# resident (who was at work) the concerns aligns to
# dampness being observed in areas of the property with
# stale odours also detected at times. On arrival the property appeared to be in general good order although
# some areas did display localised spoiling likely due to the overriding condition of the structure.
# A moisture profile was conducted through the property in order to assist determining a pattern through
# the dwelling as a whole and not just singular aspects (section 4.0).
# The readings were elevated in many areas both to internal and external walls. The floor also emitted
# elevated readings where was possible to the thermoplastic floor tiling and, can be considered a normal
# phenomena since the tiling will be acting as a DPM for ground moisture in the slab.
# However, a review of exposed floor areas indicated a number of gaps in the membrane and even some
# tiles removed resulting in a clear observation of the residual bitumen. This absence of a DPM will enable
# ground moisture to evaporate into the structure raising the potential for secondary issues. And, as it was
# notable in a number of areas, it remains highly likely why some areas of the installed timber floor also
# emitted elevated moisture readings.
# With this in mind, there remains a feasible problem with the membrane coverage as whole in the property
# resulting in the elevated readings obtained throughout. Also, in some areas the skirtings emitted elevated
# moisture levels and could likely be due to their contact with the ground or through the localised walls
# where they may be in contact with the concrete slab.
# To the exterior there was evidence of cavity wall insulation (CWI) with a number of drill holes noted and,
# what cannot be ruled out from the external wall perspective is the overall condition of the CWI in terms
# of its dampness as this can also act as a bridge for moisture to travel to the inner leaf and wet the internal
# walls.
# © Cornerstone Management Services Ltd 2009.
# Reg Office: 24 Picton House Hussar Court Westside View Waterlooville Hants PO7 7SQ
# Tel: 0344 846 0955 E: enquiries@cornerstone-ltd.co.uk W: www.cornerstone-ltd.co.uk
# No part of this document is to be reproduced without the prior consent of Cornerstone Management Services Ltd.
# Cornerstone Technical Report
# Whilst on site an assessment was undertaken of the installed ventilation measures with forced extractors
# installed in the bathroom and kitchen as this can also impact the internal conditions particularly in the
# colder periods of the year. Of note, trickle vents were installed in these rooms also and, they can also
# compromise the extractor performance by being able to draw air in from the exterior rather than from the
# rooms.
# A test of the bathroom extractor suggested it’s flow rate is compatible with the Part F of the Building Regs
# when on boost and a secondary boost function which is manually selected. However, for its optimum
# performance delivery it is recommended guidance is given to the tenant to keep the nearby window closed
# when this is operating for it to withdraw moist air from the property and not draw air in and straight out
# from the exterior. In addition, Part F of the Building Regs suggest a 10mm door undercut to enable ‘make-
# up’ air to be drawn into the bathroom from the dwelling and expel all moist air to the exterior. This door
# did not comply with the recommendations and hence, after the room is used, the difference in vapour
# pressure will result in the warm moist atmosphere circulating the property.
# In the kitchen the wall mounted device was switched off at the isolator and the tested flow rate was not
# compliant with the applicable regs. Also, with a variable door undercut, using the kitchen will also likely
# encourage atmospheric moisture to circulate the dwelling raising the potential for secondary issues.
# To conclude, it is the opinion of the author, there are indeed elevated moisture readings to the majority
# of the external and internal lower walls and, with notable gaps in the thermoplastic membrane acting as
# a DPM for ground moisture, the ongoing presence of ground moisture is a likely contributor to the
# reported damp related issues. This was endorsed by expected high readings taken on the exposed floor
# confirming its construction hence, it is recommended the floor covering as a whole is checked alongside
# the removal of all skirtings to assess the presence of a membrane to the lower wall from the floor. The
# introduction of a liquid DPM cannot be ruled out as a possible option to reduce this issue.
# In addition, the presence and condition of the CWI should be checked to ensure this is not a contributory
# factor also to the external walls because the addition of open air bricks can affect their condition.
# 3.1 Recommendations:
# Landlord:
# Measures recommended to alleviate moisture/mould related issues at the property and assist you in
# controlling internal atmospheric conditions include:
# • Consider uplifting all current floor finishes and skirtings to investigate the presence and integrity
# of the current thermoplastic DPM.
# • Confirm the requirement for a consistent membrane coverage and the inclusion of the lower
# walls.
# • Inspect the external wall cavities by removing a small number of single bricks to ascertain the type
# of CWI installed and its current condition such that, if it is compromised and/or wet, its removal
# should be considered possibly due to the presence of open air bricks.
# • Review the kitchen and bathroom door undercut for a 10mm gap to aid the extractor
# performance.
# • Review the kitchen unit for performance compliance in line with Part F of the building Regs.
# Tenants:
# • Keep the trickle vents closed in the Kitchen and Bathroom when the extractors are working.
# • After use, keep the doors to the kitchen and bathroom closed until the forced extraction has
# cleared the room of generated atmospheric moisture.
# © Cornerstone Management Services Ltd 2009.
# Reg Office: 24 Picton House Hussar Court Westside View Waterlooville Hants PO7 7SQ
# Tel: 0344 846 0955 E: enquiries@cornerstone-ltd.co.uk W: www.cornerstone-ltd.co.uk
# No part of this document is to be reproduced without the prior consent of Cornerstone Management Services Ltd.
# Cornerstone Technical Report
# 4.0 Moisture survey:
# 4.1 Moisture map
# (not to scale):
# 4.2 Structural wall readings:
# Walls Skirtings Base wall REL(PS)
# Comments
# Loc. %MC %WME Base Middle Top
# A 26.0 22.3 317 167 Salts damage at base of wall
# B 23.9 18.7 229 166
# C 36.1 In cupboard
# D 32.1 14.6 220 160
# E 21.2 245 121 11.4% MC in Boxing
# F 20.0 172 165
# G 16.9 8.6 178 167
# H 30.1 19.4 408 158
# I 25.7 17.2 228
# J 17.1 31.8 890 166
# K 19.3 10.5 134 131
# L 20.7 13.2 188 168
# © Cornerstone Management Services Ltd 2009.
# Reg Office: 24 Picton House Hussar Court Westside View Waterlooville Hants PO7 7SQ
# Tel: 0344 846 0955 E: enquiries@cornerstone-ltd.co.uk W: www.cornerstone-ltd.co.uk
# No part of this document is to be reproduced without the prior consent of Cornerstone Management Services Ltd.
# Cornerstone Technical Report
# 4.3 Structural floor readings:
# Loc. %MC REL(PS) Comments
# 1 22.1 Into wood floor finish
# 2 18.7
# 3 999 Onto thermoplastic tiles and is likely normal ground moisture
# 4 286 Onto vinyl
# 5 29.6
# 6 15.9 Into timber floor finish
# 7 391 Onto thermoplastic tiles
# 8 20.9
# 9 21.4
# 10 229 Non-invasive readings on vinyl surface
# High Moisture Levels
# Moderate Moisture Levels
# Low Moisture Levels
# 4.4 Atmospheric conditions:
# Location Relative Humidity % Air Temp oC Dew Point Temp oC Specific Humidity g/Kg
# Exterior 75.0 19.6 15.0 10.4
# Hallway 70.5 24.1 18.4 12.7
# Kitchen 61.5 24.8 16.9 11.5
# 5.0 Ventilation:
# 5.1 Bathroom extractor:
# This continuous running device delivered the following flow
# rates on test and is considered to be compliant with its
# capability for a bathroom:
# Constant: 6.0 l/s
# Boost 1: 19.8 l/s
# Boost 2: 26.2 l/s
# It is recommended the trickle vent in this room is closed.
# 5.2 Kitchen extractor:
# This device is located away from a cooker hood and was
# switched off at the isolator on arrival. On test it delivered a
# single flow rate of 6.1 l/s which is below that recommended
# for an extractor in a kitchen situated away from a
# cookerhood.
# Two trickle vents were also noted in this room that can
# impact the extractor performance.
# © Cornerstone Management Services Ltd 2009.
# Reg Office: 24 Picton House Hussar Court Westside View Waterlooville Hants PO7 7SQ
# Tel: 0344 846 0955 E: enquiries@cornerstone-ltd.co.uk W: www.cornerstone-ltd.co.uk
# No part of this document is to be reproduced without the prior consent of Cornerstone Management Services Ltd.
# Cornerstone Technical Report
# 6.0 Observations:
# 6.1 Hallway – survey location point A:
# Damage was evident to the lower section of the wall in this
# location and, with elevated moisture readings, it is possible
# the wall construction is being impaired by the ground slab
# and its current damp proofing measures against ground
# moisture.
# 6.2 Hallway cupboard – close to survey point B:
# A visual review of this cupboard clearly shows the absence
# of thermoplastic tiles that are likely to be acting as the
# damp proof membrane for ground moisture in the slab.
# Consideration should be given to inspecting the entire
# floor for an adequate membrane cover that could be
# readily contributing to the issues at low level on the walls.
# 6.3 Bathroom:
# The lower walls in this location also displayed similar
# elevated moisture readings however, at the time there
# appeared to be no leaks and the boxing was measured and
# found to be dry.
# CWI in this external wall should be inspected for its
# integrity and whether it is contributing to the issues at low
# level on the external walls.
# 6.4 Threshold to dining area:
# The floor covering was exposed in this area and drill holes
# were observed in the thermoplastic floor covering that
# again, can be a likely contributor to moisture in the lower
# sections of the dwelling.
# © Cornerstone Management Services Ltd 2009.
# Reg Office: 24 Picton House Hussar Court Westside View Waterlooville Hants PO7 7SQ
# Tel: 0344 846 0955 E: enquiries@cornerstone-ltd.co.uk W: www.cornerstone-ltd.co.uk
# No part of this document is to be reproduced without the prior consent of Cornerstone Management Services Ltd.
# Cornerstone Technical Report
# 6.5 Survey location point 6:
# A reading in the timber floor covering was dry at the time
# in this location and, the setting aside of a small piece
# confirmed the presence of a membrane underneath it that
# is acting to separate the floor finish from the thermoplastic
# tiles. The adjoining skirting was wet and is likely due to it
# being in contact with the floor and/or wet wall.
# 6.6 Survey location point J:
# Evidence of previous gripper rods were noted in the
# thermoplastic floor finish and, with rusty elements noted,
# confirms the installation of the rods penetrated the tile
# resulting in moisture able to travel up to the interior and,
# likely rotting the previous gripper.
# 6.7 Floor finishes:
# There are varied floor finishes noted throughout the
# dwelling and, could align to areas that have either gone
# into failure of been lifted to inspect and/or repair.
# It is recommended the entire floor finish is lifted to inspect
# the thermoplastic damp proof membrane and its alignment
# to all the skirtings and walls
# 6.7.1 Floor finishes:
# This image upholds the comments in 6.7 above with
# damage noted to areas of the thermoplastic tiling and
# varied timber remediations etc that can suggest a history
# of damp related issues to the flooring in this property.
# © Cornerstone Management Services Ltd 2009.
# Reg Office: 24 Picton House Hussar Court Westside View Waterlooville Hants PO7 7SQ
# Tel: 0344 846 0955 E: enquiries@cornerstone-ltd.co.uk W: www.cornerstone-ltd.co.uk
# No part of this document is to be reproduced without the prior consent of Cornerstone Management Services Ltd.
# Cornerstone Technical Report
# 6.8 Exterior:
# An inspection of the exterior did not show any issues with
# potential bridging of the DPC or rainwater elements that
# may be leaking.
# However, there was evidence of drill holes across all the
# elevations and could suggest the presence of CWI. With this
# in mind, it is recommended the cavity is accessed by
# removing a small number of bricks across the façade in
# order to check the presence and condition of any CWI
# because open air bricks were observed that can impact the
# integrity of installed insulation.
# 7.0 Survey Equipment:
# Non-destructive moisture readings using:
# Protimeter Surveymaster on search mode using radio frequency survey method with readings given
# numerically from 0 to 999 REL. Survey depth is approximately 5 to 15 mm depending on material
# characteristics. Please note the readings are subjective and open for interpretation, therefore they should
# not be used to indicate actual moisture content.
# Tramex MRH using electrical impedance survey method on non-wood materials the readings are given
# numerically from 0 to 99. Please note the readings are subjective and open for interpretation, therefore
# they should not be used to indicate actual moisture content. Readings taken from wood are given as a
# %mc the unit can be calibrated to wood species the readings indicated can be taken as an indication of
# wood moisture content. Survey depth up to 30 mm depending on material characteristics.
# Invasive moisture readings have been taken using a Protimeter Surveymaster reading direct % moisture
# in wood and % wood moisture equivalent (%WME) in other materials.
# Air moisture readings have been obtained using a Tramex MRH and a Protimeter Hygromaster measuring
# temperature in °C, % relative humidity and specific moisture content in g/Kg.
# Note: all readings taken with electronic metering are a guide and should be viewed with all the available
# information to gauge the true condition. However, for the purposes of this report the following readings
# can be taken as an indication that the material checked could be said to be dry back to a satisfactory level.
# Non-destructive Protimeter Surveymaster 200 REL(PS) or below in masonry guide only
# Non-destructive Tramex MRH Masonry scale 40 REL(TM) or below in masonry guide only
# Invasive moisture readings Plaster and Masonry WME 16% or below guide only.
# Invasive wood readings Below 15%
# Normal indoor wood moisture content 10% – 12%
# Air moisture readings in concrete Below 11 g/Kg Dry Air (75 %ERH at 20°C)
# Reference for Readings Table:
# Non-destructive Protimeter Surveymaster REL (PS)
# Non-destructive Tramex MRH REL (TM)
# Invasive moisture readings: Concrete: % WME
# Wood: % mc
# Air moisture readings in concrete: g/kg (DA)
# Thermal Camera: Flir 1 Edge Pro
# Anemometer: ACIN Flowfinder Mk II in calibration
# © Cornerstone Management Services Ltd 2009.
# Reg Office: 24 Picton House Hussar Court Westside View Waterlooville Hants PO7 7SQ
# Tel: 0344 846 0955 E: enquiries@cornerstone-ltd.co.uk W: www.cornerstone-ltd.co.uk
# No part of this document is to be reproduced without the prior consent of Cornerstone Management Services Ltd.
# Cornerstone Technical Report
# 8.0 Declaration:
# The data collected and noted herein is pertinent to the time and duration of the survey alongside respective observations and qualifiable data
# measurement. No responsibility can be given for any changes made post the survey that can impact on the report content as currently described.
# Any recommendations or undertakings noted herein are based on a number of key factors and not a singular aspect to support adequate and
# confident solutions.
# Equipment used are within calibration tolerances and, are recognized as a guidance notification only with detailed supporting data utilized to
# uphold any consequential recommendations and opinions.
# Where used, moisture meters are utilised for a qualitative guidance purpose only supported by correlation readings in unaffected areas of the
# same construction, orientation and behaviour. It is recognized any readings used by the electronic device can be influence by some construction
# materials hence, a qualitative measure is the only reading this device can emit.
# Any requirement for quantitative measures to endorse findings will be utilised where applicable to support the data capture and likely root
# causes.
# © Cornerstone Management Services Ltd 2009.
# Reg Office: 24 Picton House Hussar Court Westside View Waterlooville Hants PO7 7SQ
# Tel: 0344 846 0955 E: enquiries@cornerstone-ltd.co.uk W: www.cornerstone-ltd.co.uk
# No part of this document is to be reproduced without the prior consent of Cornerstone Management Services Ltd.

# %%
atmospheric_conditions = extract_atmospheric_table(raw_text)

# %%
print(atmospheric_conditions)
# Out:
# Exterior 75.0 19.6 15.0 10.4
# Hallway 70.5 24.1 18.4 12.7
# Kitchen 61.5 24.8 16.9 11.5

# %%
cleaned = clean_raw_text(raw_text)

# %%
print(cleaned)

# %%
ollama3 = identify_features(cleaned,model='llama3')

# %%
print(ollama3)

# %%
mistral = identify_features(cleaned, model='mistral')

# %%
pdf_folder = "reports/"
for filename in os.listdir(pdf_folder):
    if filename.endswith(".pdf"):
        filepath = os.path.join(pdf_folder, filename)
        print(f"\n📄 Processing: {filename}")

        full_text = extract_raw_text(filepath)

        # Extract atmospheric conditions table
        table = extract_atmospheric_table(full_text)
        if table:
            print("✅ Table found:")
            print(table)
        else:
            print("❌ No atmospheric table found.")
# Out:
# 📄 Processing: Full report sample.pdf
# ✅ Table found:
# Location Relative Humidity Air Temp. Dew Point Temp. Specific Humidity
# Exterior 86.5 8.2 6.05 6.0
# Hallway 67.0 19.1 12.8 9.0
# Bedroom 2 59.3 19.0 10.8 7.9
# Kitchen 57.9 19.5 10.9 8.0
#
# 📄 Processing: Cornerstone sample DS report.pdf
# ✅ Table found:
# Location Relative Humidity Air Temp. Dew Point Temp. Specific Humidity
# Exterior 94.0 3.3 2.4 4.7
# Ground floor 49.0 21.9 10.7 7.8
# First floor 54.0 24.1 14.2 9.7
#
# 📄 Processing: David_Bly_BN17.pdf
# ✅ Table found:
# Location Relative Humidity % Air Temp oC Dew Point Temp oC Specific Humidity g/Kg
# Exterior 75.0 19.6 15.0 10.4
# Hallway 70.5 24.1 18.4 12.7
# Kitchen 61.5 24.8 16.9 11.5
#
# 📄 Processing: David_Bly_BN18.pdf
# ❌ No atmospheric table found.
#
# 📄 Processing: David_Bly_BR1.pdf
# ✅ Table found:
# Location Relative Humidity Air Temp. Dew Point Temp. Specific Humidity
# Exterior 80.4 12.5 9.22 7.3
# Hallway 61.1 23.6 15.6 10.7
# Kitchen/Lounge 61.4 23.7 15.8 10.8
# Bedroom 2 54.6 23.7 14.0 9.6
#
# 📄 Processing: David_Bly_BN43.pdf
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P41' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P43' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P44' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P45' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P46' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P47' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P48' is an invalid float value
# ✅ Table found:
# Location Relative Humidity Air Temp. Dew Point Temp. Specific Humidity
# Exterior 92.4 12.2 11.0 8.1
# Kitchen 62.1 20.9 13.4 9.5
# Lounge 69.6 18.8 13.3 9.4
# Bathroom 66.4 18.7 12.6 9.0
# Bed 1 64.7 20.4 13.6 9.6
# Bed 2 74.2 19.3 14.6 10.3

# %%
import pandas as pd

# %%
df = pd.read_csv('outputs/all_atmospheric_data.csv')

# %%
df
# Out:
#                           Report        Location  Relative Humidity  Air Temp  \
# 0   Cornerstone sample DS report        Exterior               94.0       3.3
# 1   Cornerstone sample DS report    Ground floor               49.0      21.9
# 2   Cornerstone sample DS report     First floor               54.0      24.1
# 3                 David_Bly_BN17        Exterior               75.0      19.6
# 4                 David_Bly_BN17         Hallway               70.5      24.1
# 5                 David_Bly_BN17         Kitchen               61.5      24.8
# 6                 David_Bly_BN43        Exterior               92.4      12.2
# 7                 David_Bly_BN43         Kitchen               62.1      20.9
# 8                 David_Bly_BN43          Lounge               69.6      18.8
# 9                 David_Bly_BN43        Bathroom               66.4      18.7
# 10                David_Bly_BN43           Bed 1               64.7      20.4
# 11                David_Bly_BN43           Bed 2               74.2      19.3
# 12                 David_Bly_BR1        Exterior               80.4      12.5
# 13                 David_Bly_BR1         Hallway               61.1      23.6
# 14                 David_Bly_BR1  Kitchen/Lounge               61.4      23.7
# 15                 David_Bly_BR1       Bedroom 2               54.6      23.7
# 16            Full report sample        Exterior               86.5       8.2
# 17            Full report sample         Hallway               67.0      19.1
# 18            Full report sample       Bedroom 2               59.3      19.0
# 19            Full report sample         Kitchen               57.9      19.5
#
#     Dew Point  Specific Humidity
# 0        2.40                4.7
# 1       10.70                7.8
# 2       14.20                9.7
# 3       15.00               10.4
# 4       18.40               12.7
# 5       16.90               11.5
# 6       11.00                8.1
# 7       13.40                9.5
# 8       13.30                9.4
# 9       12.60                9.0
# 10      13.60                9.6
# 11      14.60               10.3
# 12       9.22                7.3
# 13      15.60               10.7
# 14      15.80               10.8
# 15      14.00                9.6
# 16       6.05                6.0
# 17      12.80                9.0
# 18      10.80                7.9
# 19      10.90                8.0
